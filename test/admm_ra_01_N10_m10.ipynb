# %%
import cvxpy as cp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import mra 
import selector as se

# %%
plt.rcParams['text.usetex'] = True
np.random.seed(123)

# %% [markdown]
# # Create parameters

# %%
rho = 1.
num_points = 1
eps_sublevel = 0.05
percent = 0.05

rho = 1 
res_type="primal"

num_resources = 10
num_agents = num_participants = 10

filename = "admm_resal_N%d_%.2f_n%d_m%d_%s"%(num_points, eps_sublevel, num_agents, num_resources, res_type)

# %%
num_resource_per_participant = 10
inner_size = 5

A_all, A_ineq, b_ineq = mra.resal_data(num_resources, num_participants, inner_size)

# %%
b_norm = 1

# %%
E, consensus2agent, agent2consensus, E_g = mra.resal_admm_matrices(num_agents, num_resources, A_ineq, A_all)
E_g = None

public_var_size = len(consensus2agent)
private_var_size = sum([agent2consensus[i].size for i in range(num_agents + 1)])
print(f"{public_var_size=}, {private_var_size=}")
# Out:
# public_var_size=100, private_var_size=200

# %% [markdown]
# # CVXPY centralized solution

# %%
true_x, true_f, true_lamb  = mra.centralized_solution_resal_admm(A_all, E, A_ineq, b_ineq, E_g)
print(f"{true_f=}")
# Out:
# true_f=-19.457708729505523

# %%
(true_lamb.max() - true_lamb.min()) / true_lamb.max()
# Out:
# 2.0

# %%
true_x.shape, true_lamb.shape
# Out:
# ((200, 1), (200, 1))

# %%
fun_agents_eps = []
fun_agents_noisy_y = []

for i in range(num_agents):
    fun_agents_eps += [lambda z_k, lamb_k, K, i=i: mra.prox_resal_query_eps_o(lamb_k, z_k, i, A_all, rho,
                                                                           eps_sublevel=eps_sublevel, num_points=K, E_g=E_g)]
    fun_agents_noisy_y += [lambda z_k, lamb_k, K, i=i: mra.prox_resal_query_noisy_price_percent(lamb_k, z_k, i, A_all, rho,
                                                                        percent=percent, num_points=K, E_g=E_g)]
    
fun_agents_eps += [lambda z_k, lamb_k, K, i=i: mra.prox_resal_g_query_eps_o(lamb_k, z_k, A_ineq, b_ineq, E_g, rho, 
                                                                           eps_sublevel=eps_sublevel, num_points=K)]
fun_agents_noisy_y += [lambda z_k, lamb_k, K, i=i: mra.prox_resal_g_query_noisy_price_percent(lamb_k, z_k, A_ineq, b_ineq, E_g, rho,
                                                                        percent=percent, num_points=K)]

fun_obj_val = lambda x_k: mra.resal_obj_value(x_k, A_all, normalized=E_g is not None)

# %% [markdown]
# # ADMM

# %%
K_i = num_points

# %%
all_results_eps, lamb_k_eps, x_k, _, mra_xk_eps  = mra.admm_consensus(fun_agents_eps, fun_obj_val, agent2consensus, consensus2agent, E, 
                                                            rho=rho, postprocessing=1, K_i=K_i, num_iters=5000, 
                                                            true_f=true_f, print_freq=100, eps_res=1e-8,
                                                            res_type=res_type, history=1)


all_results_noisy_y, lamb_k_eps, x_k, _, mra_xk_noisy_y  = mra.admm_consensus(fun_agents_noisy_y, fun_obj_val, 
                                                            agent2consensus, consensus2agent, E, 
                                                            rho=rho, postprocessing=1, K_i=K_i, num_iters=10, 
                                                            true_f=true_f, print_freq=100, eps_res=1e-8,
                                                            res_type=res_type, history=1)
# Out:
# epoch=0, f_subopt_xk=7.0728E-01,  f_subopt_mra=7.0728E-01,  viol_prim_xk=7.0700E-01,  viol_prim_mra=7.0700E-01, rel_res=1.7073E+00, 0.0000E+00
# epoch=100, f_subopt_xk=1.5356E-02,  f_subopt_mra=1.5356E-02,  viol_prim_xk=1.8482E-04,  viol_prim_mra=1.8482E-04, rel_res=5.4501E-03, 0.0000E+00
# epoch=200, f_subopt_xk=9.9144E-03,  f_subopt_mra=9.9144E-03,  viol_prim_xk=4.0027E-05,  viol_prim_mra=4.0027E-05, rel_res=3.6158E-03, 0.0000E+00
# epoch=300, f_subopt_xk=6.2448E-03,  f_subopt_mra=6.2448E-03,  viol_prim_xk=1.3373E-04,  viol_prim_mra=1.3373E-04, rel_res=2.8337E-03, 0.0000E+00
# epoch=400, f_subopt_xk=4.2142E-03,  f_subopt_mra=4.2142E-03,  viol_prim_xk=9.4849E-06,  viol_prim_mra=9.4849E-06, rel_res=2.2150E-03, 0.0000E+00
# epoch=500, f_subopt_xk=2.9363E-03,  f_subopt_mra=2.9363E-03,  viol_prim_xk=3.6455E-06,  viol_prim_mra=3.6455E-06, rel_res=1.7931E-03, 0.0000E+00
# epoch=600, f_subopt_xk=2.0603E-03,  f_subopt_mra=2.0603E-03,  viol_prim_xk=8.5107E-07,  viol_prim_mra=8.5107E-07, rel_res=1.2860E-03, 0.0000E+00
# epoch=700, f_subopt_xk=1.6083E-03,  f_subopt_mra=1.6083E-03,  viol_prim_xk=9.2845E-07,  viol_prim_mra=9.2845E-07, rel_res=9.9909E-04, 0.0000E+00
# epoch=800, f_subopt_xk=1.3794E-03,  f_subopt_mra=1.3794E-03,  viol_prim_xk=1.5366E-06,  viol_prim_mra=1.5366E-06, rel_res=6.3510E-04, 0.0000E+00
# epoch=900, f_subopt_xk=1.2426E-03,  f_subopt_mra=1.2426E-03,  viol_prim_xk=3.5269E-07,  viol_prim_mra=3.5269E-07, rel_res=6.2308E-04, 0.0000E+00
# epoch=1000, f_subopt_xk=1.1386E-03,  f_subopt_mra=1.1386E-03,  viol_prim_xk=6.2924E-07,  viol_prim_mra=6.2924E-07, rel_res=5.4040E-04, 0.0000E+00
# epoch=1100, f_subopt_xk=1.0412E-03,  f_subopt_mra=1.0412E-03,  viol_prim_xk=6.5921E-07,  viol_prim_mra=6.5921E-07, rel_res=5.0423E-04, 0.0000E+00
# epoch=1200, f_subopt_xk=9.5376E-04,  f_subopt_mra=9.5376E-04,  viol_prim_xk=4.3016E-07,  viol_prim_mra=4.3016E-07, rel_res=5.0027E-04, 0.0000E+00
# epoch=1300, f_subopt_xk=8.6756E-04,  f_subopt_mra=8.6756E-04,  viol_prim_xk=4.0984E-07,  viol_prim_mra=4.0984E-07, rel_res=4.9684E-04, 0.0000E+00
# epoch=1400, f_subopt_xk=7.8088E-04,  f_subopt_mra=7.8088E-04,  viol_prim_xk=3.8139E-07,  viol_prim_mra=3.8139E-07, rel_res=4.9355E-04, 0.0000E+00
# epoch=1500, f_subopt_xk=6.9746E-04,  f_subopt_mra=6.9746E-04,  viol_prim_xk=2.7163E-07,  viol_prim_mra=2.7163E-07, rel_res=4.9032E-04, 0.0000E+00
# epoch=1600, f_subopt_xk=6.1462E-04,  f_subopt_mra=6.1462E-04,  viol_prim_xk=3.0515E-07,  viol_prim_mra=3.0515E-07, rel_res=4.8737E-04, 0.0000E+00
# epoch=1700, f_subopt_xk=5.3187E-04,  f_subopt_mra=5.3187E-04,  viol_prim_xk=1.2659E-06,  viol_prim_mra=1.2659E-06, rel_res=4.8563E-04, 0.0000E+00
# epoch=1800, f_subopt_xk=4.8322E-04,  f_subopt_mra=4.8322E-04,  viol_prim_xk=5.2661E-07,  viol_prim_mra=5.2661E-07, rel_res=3.1713E-04, 0.0000E+00
# epoch=1900, f_subopt_xk=4.4714E-04,  f_subopt_mra=4.4714E-04,  viol_prim_xk=8.3392E-07,  viol_prim_mra=8.3392E-07, rel_res=3.1589E-04, 0.0000E+00
# epoch=2000, f_subopt_xk=4.1461E-04,  f_subopt_mra=4.1461E-04,  viol_prim_xk=3.8889E-07,  viol_prim_mra=3.8889E-07, rel_res=3.1438E-04, 0.0000E+00
# epoch=2100, f_subopt_xk=3.9359E-04,  f_subopt_mra=3.9359E-04,  viol_prim_xk=3.0639E-07,  viol_prim_mra=3.0639E-07, rel_res=2.3960E-04, 0.0000E+00
# epoch=2200, f_subopt_xk=3.7462E-04,  f_subopt_mra=3.7462E-04,  viol_prim_xk=3.5453E-07,  viol_prim_mra=3.5453E-07, rel_res=2.3917E-04, 0.0000E+00
# epoch=2300, f_subopt_xk=3.5175E-04,  f_subopt_mra=3.5175E-04,  viol_prim_xk=9.9110E-07,  viol_prim_mra=9.9110E-07, rel_res=2.3937E-04, 0.0000E+00
# epoch=2400, f_subopt_xk=3.3465E-04,  f_subopt_mra=3.3465E-04,  viol_prim_xk=3.4337E-07,  viol_prim_mra=3.4337E-07, rel_res=2.0716E-04, 0.0000E+00
# epoch=2500, f_subopt_xk=3.2025E-04,  f_subopt_mra=3.2025E-04,  viol_prim_xk=1.4320E-07,  viol_prim_mra=1.4320E-07, rel_res=2.0647E-04, 0.0000E+00
# epoch=2600, f_subopt_xk=3.0536E-04,  f_subopt_mra=3.0536E-04,  viol_prim_xk=3.3181E-07,  viol_prim_mra=3.3181E-07, rel_res=2.0618E-04, 0.0000E+00
# epoch=2700, f_subopt_xk=2.9102E-04,  f_subopt_mra=2.9102E-04,  viol_prim_xk=8.8976E-08,  viol_prim_mra=8.8976E-08, rel_res=2.0546E-04, 0.0000E+00
# epoch=2800, f_subopt_xk=2.7638E-04,  f_subopt_mra=2.7638E-04,  viol_prim_xk=9.4227E-08,  viol_prim_mra=9.4227E-08, rel_res=2.0500E-04, 0.0000E+00
# epoch=2900, f_subopt_xk=2.6194E-04,  f_subopt_mra=2.6194E-04,  viol_prim_xk=7.8145E-08,  viol_prim_mra=7.8145E-08, rel_res=2.0453E-04, 0.0000E+00
# epoch=3000, f_subopt_xk=2.4749E-04,  f_subopt_mra=2.4749E-04,  viol_prim_xk=7.6659E-08,  viol_prim_mra=7.6659E-08, rel_res=2.0408E-04, 0.0000E+00
# epoch=3100, f_subopt_xk=2.3295E-04,  f_subopt_mra=2.3295E-04,  viol_prim_xk=1.5249E-07,  viol_prim_mra=1.5249E-07, rel_res=2.0371E-04, 0.0000E+00
# epoch=3200, f_subopt_xk=2.1879E-04,  f_subopt_mra=2.1879E-04,  viol_prim_xk=8.5336E-08,  viol_prim_mra=8.5336E-08, rel_res=2.0321E-04, 0.0000E+00
# epoch=3300, f_subopt_xk=2.0438E-04,  f_subopt_mra=2.0438E-04,  viol_prim_xk=9.6183E-08,  viol_prim_mra=9.6183E-08, rel_res=2.0279E-04, 0.0000E+00
# epoch=3400, f_subopt_xk=1.9021E-04,  f_subopt_mra=1.9021E-04,  viol_prim_xk=1.0222E-07,  viol_prim_mra=1.0222E-07, rel_res=2.0238E-04, 0.0000E+00
# epoch=3500, f_subopt_xk=1.7627E-04,  f_subopt_mra=1.7627E-04,  viol_prim_xk=1.7385E-07,  viol_prim_mra=1.7385E-07, rel_res=2.0204E-04, 0.0000E+00
# epoch=3600, f_subopt_xk=1.6197E-04,  f_subopt_mra=1.6197E-04,  viol_prim_xk=8.4970E-08,  viol_prim_mra=8.4970E-08, rel_res=2.0155E-04, 0.0000E+00
# epoch=3700, f_subopt_xk=1.4789E-04,  f_subopt_mra=1.4789E-04,  viol_prim_xk=8.9796E-08,  viol_prim_mra=8.9796E-08, rel_res=2.0115E-04, 0.0000E+00
# epoch=3800, f_subopt_xk=1.3387E-04,  f_subopt_mra=1.3387E-04,  viol_prim_xk=8.9332E-08,  viol_prim_mra=8.9332E-08, rel_res=2.0076E-04, 0.0000E+00
# epoch=3900, f_subopt_xk=1.1990E-04,  f_subopt_mra=1.1990E-04,  viol_prim_xk=8.0725E-08,  viol_prim_mra=8.0725E-08, rel_res=2.0037E-04, 0.0000E+00
# epoch=4000, f_subopt_xk=1.0882E-04,  f_subopt_mra=1.0882E-04,  viol_prim_xk=5.2890E-06,  viol_prim_mra=5.2890E-06, rel_res=1.2671E-04, 0.0000E+00
# epoch=4100, f_subopt_xk=1.0183E-04,  f_subopt_mra=1.0183E-04,  viol_prim_xk=2.6468E-07,  viol_prim_mra=2.6468E-07, rel_res=1.2142E-04, 0.0000E+00
# epoch=4200, f_subopt_xk=9.6649E-05,  f_subopt_mra=9.6649E-05,  viol_prim_xk=1.7427E-07,  viol_prim_mra=1.7427E-07, rel_res=1.2107E-04, 0.0000E+00
# epoch=4300, f_subopt_xk=9.1571E-05,  f_subopt_mra=9.1571E-05,  viol_prim_xk=1.4001E-07,  viol_prim_mra=1.4001E-07, rel_res=1.2078E-04, 0.0000E+00
# epoch=4400, f_subopt_xk=8.5996E-05,  f_subopt_mra=8.5996E-05,  viol_prim_xk=3.9052E-07,  viol_prim_mra=3.9052E-07, rel_res=1.2076E-04, 0.0000E+00
# epoch=4500, f_subopt_xk=8.1168E-05,  f_subopt_mra=8.1168E-05,  viol_prim_xk=2.3845E-07,  viol_prim_mra=2.3845E-07, rel_res=1.2035E-04, 0.0000E+00
# epoch=4600, f_subopt_xk=7.6277E-05,  f_subopt_mra=7.6277E-05,  viol_prim_xk=1.6852E-07,  viol_prim_mra=1.6852E-07, rel_res=1.2002E-04, 0.0000E+00
# epoch=4700, f_subopt_xk=7.1324E-05,  f_subopt_mra=7.1324E-05,  viol_prim_xk=1.3337E-07,  viol_prim_mra=1.3337E-07, rel_res=1.1973E-04, 0.0000E+00
# epoch=4800, f_subopt_xk=6.6446E-05,  f_subopt_mra=6.6446E-05,  viol_prim_xk=1.0872E-07,  viol_prim_mra=1.0872E-07, rel_res=1.1945E-04, 0.0000E+00
# epoch=4900, f_subopt_xk=6.0638E-05,  f_subopt_mra=6.0638E-05,  viol_prim_xk=5.3990E-07,  viol_prim_mra=5.3990E-07, rel_res=1.1963E-04, 0.0000E+00
# epoch=4999, f_subopt_xk=5.6926E-05,  f_subopt_mra=5.6926E-05,  viol_prim_xk=2.4143E-07,  viol_prim_mra=2.4143E-07, rel_res=1.1908E-04, 0.0000E+00
# epoch=0, f_subopt_xk=7.0727E-01,  f_subopt_mra=7.0727E-01,  viol_prim_xk=7.0700E-01,  viol_prim_mra=7.0700E-01, rel_res=1.7073E+00, 0.0000E+00
# /Users/tepars/anaconda3/envs/py311/lib/python3.11/site-packages/cvxpy/problems/problem.py:1407: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# epoch=9, f_subopt_xk=5.1381E-03,  f_subopt_mra=5.1381E-03,  viol_prim_xk=2.6737E-02,  viol_prim_mra=2.6737E-02, rel_res=5.2188E-02, 0.0000E+00

# %%
if len(all_results_noisy_y["subopt_xk"]) > len(all_results_eps["subopt_xk"]):
    all_res = all_results_noisy_y
else:
    all_res = all_results_eps

# %%
T = 5000

# %%
mra.plot_all_methods_metrics_4x(all_results_eps, all_results_noisy_y, true_f, 
                                b_norm, percent, eps_sublevel, None, T, admm=True)
