# %%
import cvxpy as cp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import mra 
import selector as se

# %%
plt.rcParams['text.usetex'] = True
np.random.seed(123)

# %% [markdown]
# # Create parameters

# %%
rho = 1.
num_points = 10
eps_sublevel = percent = 0.1

alpha = 1 # proximal term coefficient
history = 1
res_type="primal"

num_agents = num_packages = 200
num_fcs = 50

# num_agents = num_packages = 40
# num_fcs = 9

filename = "ncvx_ap_N%d_%.2f_n%d_m%d_H%d_%s"%(num_points, eps_sublevel, num_agents, num_fcs, history, res_type)

# %%
econ, A_ineq, b_ineq = mra.ap_data(num_packages, num_fcs)

# %%
b_norm = np.linalg.norm(b_ineq)

# %% [markdown]
# # CVXPY centralized solution

# %%
cvx_true_xp, cvx_true_xf, cvx_true_f, true_lamb, cvx_true_prob = mra.assignment_problem_milp_solution(num_packages, num_fcs, econ,  
                                                                                     integer=False)
# print(f"{cvx_true_f=} \n{cvx_true_prob.status} \n{true_lamb=} \n{cvx_true_xf=}")
print(f"{cvx_true_f=}")
# Out:
# cvx_true_f=-90.29596235198767

# %% [markdown]
# # MILP centralized solution

# %%
true_xp, true_xf, true_f, _, true_prob = mra.assignment_problem_milp_solution(num_packages, num_fcs, econ,  
                                                                                     integer=True, solver=cp.GUROBI, verbose=True, 
                                                                                     mipgap=0.01, timelimit=150)
print(f"{true_f=} \n{true_prob.status} \n{true_xf=}")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2606542
# Academic license - for non-commercial use only - expires 2026-01-06
# Set parameter TimeLimit to value 150
# Set parameter MIPGap to value 0.01
# ===============================================================================
#                                      CVXPY
#                                      v1.3.1
# ===============================================================================
# (CVXPY) Jan 31 10:07:51 PM: Your problem has 20100 variables, 651 constraints, and 0 parameters.
# (CVXPY) Jan 31 10:07:51 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 31 10:07:51 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 31 10:07:51 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 31 10:07:51 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Jan 31 10:07:51 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Jan 31 10:07:51 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 31 10:07:51 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Jan 31 10:07:51 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Jan 31 10:07:51 PM: Applying reduction GUROBI
# (CVXPY) Jan 31 10:07:51 PM: Finished problem compilation (took 3.310e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 31 10:07:51 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 20500 rows, 20150 columns and 50400 nonzeros
# Model fingerprint: 0xcf988731
# Model has 50 quadratic objective terms
# Variable types: 10150 continuous, 10000 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [7e-05, 1e+00]
#   QObjective range [9e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
#
# User MIP start produced solution with objective 0 (0.01s)
# Loaded user MIP start with objective 0
#
# Presolve removed 20250 rows and 10100 columns
# Presolve time: 0.05s
# Presolved: 250 rows, 10050 columns, 20050 nonzeros
# Presolved model has 50 quadratic objective terms
# Variable types: 50 continuous, 10000 integer (10000 binary)
# Found heuristic solution: objective -54.9606694
#
# Root relaxation: objective -9.029596e+01, 857 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -90.29596    0   94  -54.96067  -90.29596  64.3%     -    0s
# H    0     0                     -70.0224297  -90.29596  29.0%     -    0s
# H    0     0                     -84.0760221  -90.29596  7.40%     -    0s
# H    0     0                     -84.0919961  -90.29596  7.38%     -    0s
# H    0     0                     -84.1024485  -90.29596  7.36%     -    0s
# H    0     0                     -84.2171556  -90.29596  7.22%     -    0s
#      0     0  -90.28750    0   94  -84.21716  -90.28750  7.21%     -    0s
# H    0     0                     -84.2306734  -90.28750  7.19%     -    0s
# H    0     0                     -84.3324134  -90.28750  7.06%     -    0s
#      0     2  -90.28750    0   94  -84.33241  -90.28750  7.06%     -    0s
# H   32    40                     -84.3939805  -90.27193  6.96%  16.1    2s
# H   34    40                     -84.3971871  -90.27193  6.96%  15.8    2s
# H   36    40                     -84.3973721  -90.27193  6.96%  15.7    2s
# H   37    40                     -84.4371811  -90.27193  6.91%  15.8    2s
#   2708  2812  -88.25519  307   79  -84.43718  -90.27031  6.91%  13.4    5s
# H 6140  5995                     -84.4591937  -90.27031  6.88%  10.3    7s
# H 6152  5993                     -84.4621960  -90.27031  6.88%  10.3    7s
#   7524  6821  -90.24380   14   95  -84.46220  -90.26687  6.87%   9.5   10s
# H 7526  6481                     -84.4703488  -90.26687  6.86%   9.5   10s
#  12684 10114  -88.31619  372   81  -84.47035  -90.26521  6.86%  10.1   15s
#  19476 14202  -86.30177  771   62  -84.47035  -90.26521  6.86%   9.5   20s
#  24930 16513  -84.85599 1204   51  -84.47035  -90.26521  6.86%   9.4   25s
#  31088 22073  -86.09380  648   69  -84.47035  -90.26344  6.86%   9.3   30s
# H37489 26153                     -84.4759454  -90.26025  6.85%   9.3   34s
#  39287 28636  -88.28118  346   81  -84.47595  -90.26025  6.85%   9.4   35s
#  47591 36094  -89.47087  107   93  -84.47595  -90.24317  6.83%   9.4   40s
#  59508 46960  -88.78447  241   89  -84.47595  -90.23070  6.81%   9.7   45s
#  72763 59091  -88.09477  377   81  -84.47595  -90.23022  6.81%   9.8   50s
#  84662 69503  -84.70388 1176   37  -84.47595  -90.22831  6.81%   9.9   55s
#  93157 77561  -90.03758   35   91  -84.47595  -90.21926  6.80%  10.0   60s
#  106671 90219  -89.45080   98   85  -84.47595  -90.21445  6.79%  10.1   65s
#  120342 102023  -89.34099  107   87  -84.47595  -90.21052  6.79%  10.0   70s
#  132200 112418  -89.57185  106   84  -84.47595  -90.20751  6.78%  10.2   75s
#  143612 122715  -89.81367   66   91  -84.47595  -90.20707  6.78%  10.1   80s
#  153424 131743  -89.76294   64   85  -84.47595  -90.20496  6.78%  10.1   85s
#  162181 139906  -87.73117  503   81  -84.47595  -90.20496  6.78%  10.2   91s
#  171901 148830  -85.37679  954   48  -84.47595  -90.20496  6.78%  10.1   95s
#  183200 158927  -85.38266  975   39  -84.47595  -90.19959  6.78%  10.1  100s
#  194349 168846  -84.93855 1137   33  -84.47595  -90.19756  6.77%  10.1  105s
#  203844 177605  -89.35284  130   83  -84.47595  -90.19473  6.77%  10.1  110s
#  216485 187486  -88.79878  180   86  -84.47595  -90.19343  6.77%  10.0  115s
#  226844 196942  -88.98760  209   87  -84.47595  -90.19232  6.77%  10.0  120s
#  237568 206728  -86.30485  161   71  -84.47595  -90.19016  6.76%  10.0  125s
#  247218 215241  -89.53375   93   84  -84.47595  -90.18954  6.76%  10.1  130s
#  253604 219983  -86.96472  671   72  -84.47595  -90.18954  6.76%  10.0  135s
#  262386 228352  -89.40597  135   88  -84.47595  -90.18760  6.76%  10.0  140s
#  273612 238855  -86.45691  629   54  -84.47595  -90.18718  6.76%  10.0  145s
#  286504 250308  -88.84672  244   87  -84.47595  -90.18550  6.76%  10.1  150s
#
# Explored 286755 nodes (2891716 simplex iterations) in 150.01 seconds (232.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -84.4759 -84.4703 -84.4622 ... -84.2307
#
# Time limit reached
# Best objective -8.447594541035e+01, best bound -9.018549729796e+01, gap 6.7588%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 31 10:10:21 PM: Problem status: user_limit
# (CVXPY) Jan 31 10:10:21 PM: Optimal value: -8.448e+01
# (CVXPY) Jan 31 10:10:21 PM: Compilation took 3.310e-01 seconds
# (CVXPY) Jan 31 10:10:21 PM: Solver (including time spent in interface) took 1.502e+02 seconds
# true_f=-84.47594541035264
# user_limit
# true_xf=array([2., 2., 3., 2., 2., 2., 1., 2., 1., 2., 2., 2., 3., 2., 3., 3., 2.,
#        2., 1., 2., 3., 2., 1., 1., 3., 1., 2., 2., 2., 2., 2., 3., 2., 2.,
#        1., 3., 1., 3., 2., 2., 2., 3., 2., 2., 2., 2., 2., 1., 2., 3.])
# /Users/parshakova.tanya/opt/anaconda3/envs/osbdo/lib/python3.9/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
plt.imshow(true_xp, aspect='auto')

# %%
true_lamb.shape, true_xp.size + true_xf.size
# Out:
# ((50,), 10050)

# %%
mra.assignment_problem_milp_solution_lamb(true_lamb, num_packages, num_fcs, econ, integer=True)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2606542
# Academic license - for non-commercial use only - expires 2026-01-06
# -90.29596327465502

# %%
fun_agents_eps = []
fun_agents_noisy_y = []

for i in range(num_packages):
    fun_agents_eps += [lambda lamb_k, K, i=i: mra.package_agent_query_multiple_actions(lamb_k, i, num_fcs,
                                                                                  econ, eps_sublevel=eps_sublevel, K=K,  
                                                                                  return_best=True, integer=True)]
    fun_agents_noisy_y += [lambda lamb_k, K, i=i: mra.package_agent_query_multiple_actions_noisy_prices(lamb_k, i, num_fcs,
                                                                                  econ, percent=percent, K=K,  
                                                                                  return_best=True, integer=True)]
 
for i in range(num_packages, num_packages+num_fcs):
    fun_agents_eps += [lambda lamb_k, K, i=i: mra.fc_agent_query_multiple_actions(lamb_k, i-num_packages, 
                                                                          econ, eps_sublevel=eps_sublevel, K=K, return_best=True)]
    fun_agents_noisy_y += [lambda lamb_k, K, i=i: mra.fc_agent_query_multiple_actions_noisy_prices(lamb_k, i-num_packages, 
                                                                          econ, percent=percent, K=K, return_best=True)]


fun_obj_val = lambda x_k: mra.assignment_problem_obj_val(x_k, num_packages, num_fcs, econ, integer=False)

# %% [markdown]
# # Localization

# %%
price_max = 3 * true_lamb.max()
price_min = (1./3) * true_lamb.min()
K_i = num_points
N = num_agents
primal_var_size = A_ineq.shape[1]

# %%
all_results_noisy_y, lamb_k_eps, _, x_k, _, mra_xk_noisy_y  = mra.price_localization_primal_recovery(fun_agents_noisy_y, fun_obj_val, primal_var_size, 
                                                                                                      A_ineq=A_ineq, b_ineq=b_ineq, 
                                                            price_max=price_max, price_min=price_min, alpha=alpha, relaxed=False, 
                                                            postprocessing=1, K_i=K_i, num_iters=100, 
                                                            method="accpm_l2", true_f=true_f, print_freq=5, eps_lamb=1e-28,
                                                            res_type=res_type, history=history)
# Out:
# /Users/parshakova.tanya/Documents/projects/mra_precovery/mra/localization_prim_rec.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   lamb_rel_diff = np.linalg.norm(lamb_k - lamb_prev) / np.linalg.norm(lamb_prev)
# epoch=0, f_subopt_xk=1.3234E+00,  f_subopt_mra=1.2720E+00,  viol_xk=1.3706E+02, viol_mra=1.3252E+02, lamb_rel_diff=INF
# epoch=5, f_subopt_xk=8.1012E-01,  f_subopt_mra=4.7125E-01,  viol_xk=2.2882E+02, viol_mra=1.0495E+02, lamb_rel_diff=6.8410E-02
# epoch=10, f_subopt_xk=1.5100E-01,  f_subopt_mra=8.2716E-02,  viol_xk=8.2211E+01, viol_mra=3.0660E+01, lamb_rel_diff=6.1865E-02
# epoch=15, f_subopt_xk=9.1551E-02,  f_subopt_mra=7.5418E-02,  viol_xk=7.8628E+01, viol_mra=2.8792E+01, lamb_rel_diff=5.8851E-02
# epoch=20, f_subopt_xk=8.7610E-02,  f_subopt_mra=7.3827E-02,  viol_xk=7.5588E+01, viol_mra=2.6077E+01, lamb_rel_diff=5.8195E-02
# epoch=25, f_subopt_xk=8.3784E-02,  f_subopt_mra=6.8130E-02,  viol_xk=6.8182E+01, viol_mra=2.4869E+01, lamb_rel_diff=5.8115E-02
# epoch=30, f_subopt_xk=8.3717E-02,  f_subopt_mra=7.0848E-02,  viol_xk=7.7719E+01, viol_mra=2.3650E+01, lamb_rel_diff=5.5542E-02
# epoch=35, f_subopt_xk=8.8843E-02,  f_subopt_mra=6.9962E-02,  viol_xk=6.5941E+01, viol_mra=2.4699E+01, lamb_rel_diff=5.6912E-02
# epoch=40, f_subopt_xk=8.5098E-02,  f_subopt_mra=7.1693E-02,  viol_xk=7.5382E+01, viol_mra=2.3809E+01, lamb_rel_diff=5.3954E-02
# epoch=45, f_subopt_xk=8.2339E-02,  f_subopt_mra=7.4168E-02,  viol_xk=7.1699E+01, viol_mra=2.3691E+01, lamb_rel_diff=5.5486E-02
# epoch=50, f_subopt_xk=7.9055E-02,  f_subopt_mra=6.8227E-02,  viol_xk=7.1921E+01, viol_mra=2.3319E+01, lamb_rel_diff=5.4798E-02
# epoch=55, f_subopt_xk=8.0381E-02,  f_subopt_mra=7.1538E-02,  viol_xk=6.4770E+01, viol_mra=2.2877E+01, lamb_rel_diff=4.8891E-02
# epoch=60, f_subopt_xk=7.9884E-02,  f_subopt_mra=6.4932E-02,  viol_xk=7.3964E+01, viol_mra=2.3677E+01, lamb_rel_diff=5.2168E-02
# epoch=65, f_subopt_xk=7.8479E-02,  f_subopt_mra=6.8728E-02,  viol_xk=6.6336E+01, viol_mra=2.3025E+01, lamb_rel_diff=4.5300E-02
# epoch=70, f_subopt_xk=7.9853E-02,  f_subopt_mra=6.5795E-02,  viol_xk=6.8975E+01, viol_mra=2.4144E+01, lamb_rel_diff=4.8041E-02
# epoch=75, f_subopt_xk=8.3810E-02,  f_subopt_mra=6.8159E-02,  viol_xk=5.9311E+01, viol_mra=2.3018E+01, lamb_rel_diff=4.0049E-02
# epoch=80, f_subopt_xk=8.4989E-02,  f_subopt_mra=6.3243E-02,  viol_xk=4.6676E+01, viol_mra=2.3119E+01, lamb_rel_diff=3.8661E-02
# epoch=85, f_subopt_xk=7.4944E-02,  f_subopt_mra=5.8745E-02,  viol_xk=6.4213E+01, viol_mra=2.3928E+01, lamb_rel_diff=3.8270E-02
# epoch=90, f_subopt_xk=7.5069E-02,  f_subopt_mra=5.8077E-02,  viol_xk=4.8563E+01, viol_mra=2.2934E+01, lamb_rel_diff=3.4207E-02
# epoch=95, f_subopt_xk=7.5304E-02,  f_subopt_mra=5.7191E-02,  viol_xk=4.5513E+01, viol_mra=2.2835E+01, lamb_rel_diff=3.6695E-02
# epoch=99, f_subopt_xk=7.1389E-02,  f_subopt_mra=5.5863E-02,  viol_xk=6.1311E+01, viol_mra=2.2618E+01, lamb_rel_diff=2.5192E-02

# %%
all_results_eps, lamb_k_eps, _, x_k, _, mra_xk_eps  = mra.price_localization_primal_recovery(fun_agents_eps, fun_obj_val, primal_var_size, A_ineq=A_ineq, b_ineq=b_ineq, 
                                                            price_max=price_max, price_min=price_min, alpha=alpha, relaxed=False, 
                                                            postprocessing=1, K_i=K_i, num_iters=100, 
                                                            method="accpm_l2", true_f=true_f, print_freq=5, eps_lamb=1e-28,
                                                            res_type=res_type, history=history)
# Out:
# epoch=0, f_subopt_xk=1.3234E+00,  f_subopt_mra=1.0474E+00,  viol_xk=1.3706E+02, viol_mra=1.0278E+02, lamb_rel_diff=INF
# epoch=5, f_subopt_xk=8.1012E-01,  f_subopt_mra=6.4948E-01,  viol_xk=2.2882E+02, viol_mra=1.6164E+02, lamb_rel_diff=6.8410E-02
# epoch=10, f_subopt_xk=1.5100E-01,  f_subopt_mra=3.1406E-02,  viol_xk=8.2211E+01, viol_mra=2.3473E+01, lamb_rel_diff=6.1865E-02
# epoch=15, f_subopt_xk=9.1551E-02,  f_subopt_mra=1.9170E-02,  viol_xk=7.8628E+01, viol_mra=8.6894E+00, lamb_rel_diff=5.8851E-02
# epoch=20, f_subopt_xk=8.7610E-02,  f_subopt_mra=9.4118E-03,  viol_xk=7.5588E+01, viol_mra=8.6374E+00, lamb_rel_diff=5.8195E-02
# epoch=25, f_subopt_xk=8.3784E-02,  f_subopt_mra=3.0678E-03,  viol_xk=6.8182E+01, viol_mra=7.0406E+00, lamb_rel_diff=5.8115E-02
# epoch=30, f_subopt_xk=8.3717E-02,  f_subopt_mra=1.7059E-02,  viol_xk=7.7719E+01, viol_mra=8.4177E+00, lamb_rel_diff=5.5542E-02
# epoch=35, f_subopt_xk=8.8843E-02,  f_subopt_mra=8.9177E-03,  viol_xk=6.5941E+01, viol_mra=6.2541E+00, lamb_rel_diff=5.6912E-02
# epoch=40, f_subopt_xk=8.5098E-02,  f_subopt_mra=1.5986E-02,  viol_xk=7.5382E+01, viol_mra=7.0607E+00, lamb_rel_diff=5.3954E-02
# epoch=45, f_subopt_xk=8.2339E-02,  f_subopt_mra=6.9046E-03,  viol_xk=7.1699E+01, viol_mra=4.8365E+00, lamb_rel_diff=5.5486E-02
# epoch=50, f_subopt_xk=7.9055E-02,  f_subopt_mra=1.4527E-03,  viol_xk=7.1921E+01, viol_mra=6.8902E+00, lamb_rel_diff=5.4798E-02
# epoch=55, f_subopt_xk=8.0381E-02,  f_subopt_mra=1.5198E-02,  viol_xk=6.4770E+01, viol_mra=6.2987E+00, lamb_rel_diff=4.8891E-02
# epoch=60, f_subopt_xk=7.9884E-02,  f_subopt_mra=6.8887E-03,  viol_xk=7.3964E+01, viol_mra=5.2626E+00, lamb_rel_diff=5.2168E-02
# epoch=65, f_subopt_xk=7.8479E-02,  f_subopt_mra=5.0832E-03,  viol_xk=6.6336E+01, viol_mra=4.5033E+00, lamb_rel_diff=4.5300E-02
# epoch=70, f_subopt_xk=7.9853E-02,  f_subopt_mra=1.2415E-02,  viol_xk=6.8975E+01, viol_mra=5.3421E+00, lamb_rel_diff=4.8041E-02
# epoch=75, f_subopt_xk=8.3810E-02,  f_subopt_mra=7.4492E-03,  viol_xk=5.9311E+01, viol_mra=4.0628E+00, lamb_rel_diff=4.0049E-02
# epoch=80, f_subopt_xk=8.4989E-02,  f_subopt_mra=1.4718E-02,  viol_xk=4.6676E+01, viol_mra=3.8832E+00, lamb_rel_diff=3.8661E-02
# epoch=85, f_subopt_xk=7.4944E-02,  f_subopt_mra=1.5727E-02,  viol_xk=6.4213E+01, viol_mra=3.7656E+00, lamb_rel_diff=3.8270E-02
# epoch=90, f_subopt_xk=7.5069E-02,  f_subopt_mra=2.0842E-02,  viol_xk=4.8563E+01, viol_mra=3.7419E+00, lamb_rel_diff=3.4207E-02
# epoch=95, f_subopt_xk=7.5304E-02,  f_subopt_mra=1.7506E-02,  viol_xk=4.5513E+01, viol_mra=3.5128E+00, lamb_rel_diff=3.6695E-02
# epoch=99, f_subopt_xk=7.1389E-02,  f_subopt_mra=1.4469E-02,  viol_xk=6.1311E+01, viol_mra=3.7989E+00, lamb_rel_diff=2.5192E-02

# %%
mra_xk_eps[:-num_fcs].sum(), num_packages
# Out:
# (102.0, 200)

# %%
mra_xk_noisy_y[:-num_fcs].sum(), num_packages
# Out:
# (102.0, 200)

# %%
if len(all_results_noisy_y["subopt_xk"]) > len(all_results_eps["subopt_xk"]):
    all_res = all_results_noisy_y
else:
    all_res = all_results_eps

# %%
import pickle

with open(f"../results/{filename}_dict.pkl", "wb") as file:
    pickle.dump({"eps":all_results_eps, "noisy_y":all_results_noisy_y}, file)
with open(f"../results/{filename}_dict.pkl", "rb") as file:
    res = pickle.load(file)

# %%
print("sub_eps", np.array(all_results_eps["viol_primal_prec"]).size,
      "noisy_y", np.array(all_results_noisy_y["viol_primal_prec"]).size)

# %%
mra.plot_all_methods_metrics_4x(all_results_eps, all_results_noisy_y, true_f, 
                                b_norm, percent, eps_sublevel, filename)
