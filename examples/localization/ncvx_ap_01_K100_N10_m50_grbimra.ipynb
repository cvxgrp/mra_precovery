# %%
import cvxpy as cp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import mra 
import selector as se

# %%
plt.rcParams['text.usetex'] = True
np.random.seed(123)

# %% [markdown]
# # Create parameters

# %%
rho = 1.
num_points = 10
eps_sublevel = percent = 0.1

alpha = 1 # proximal term coefficient
history = 1
res_type="primal"

num_agents = num_packages = 200
num_fcs = 50

# num_agents = num_packages = 40
# num_fcs = 9

filename = "ncvx_grbmra_ap_N%d_%.2f_n%d_m%d_H%d_%s"%(num_points, eps_sublevel, num_agents, num_fcs, history, res_type)

# %%
econ, A_ineq, b_ineq = mra.ap_data(num_packages, num_fcs)

# %%
b_norm = np.linalg.norm(b_ineq)

# %% [markdown]
# # CVXPY centralized solution

# %%
cvx_true_xp, cvx_true_xf, cvx_true_f, true_lamb, cvx_true_prob = mra.assignment_problem_milp_solution(num_packages, num_fcs, econ,  
                                                                                     integer=False)
# print(f"{cvx_true_f=} \n{cvx_true_prob.status} \n{true_lamb=} \n{cvx_true_xf=}")
print(f"{cvx_true_f=}")
# Out:
# cvx_true_f=-90.29596235198767

# %% [markdown]
# # MILP centralized solution

# %%
true_xp, true_xf, true_f, _, true_prob = mra.assignment_problem_milp_solution(num_packages, num_fcs, econ,  
                                                                                     integer=True, solver=cp.GUROBI, verbose=True, 
                                                                                     mipgap=0.01, timelimit=150)
print(f"{true_f=} \n{true_prob.status} \n{true_xf=}")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2606542
# Academic license - for non-commercial use only - expires 2026-01-06
# Set parameter TimeLimit to value 150
# Set parameter MIPGap to value 0.01
# ===============================================================================
#                                      CVXPY
#                                      v1.3.1
# ===============================================================================
# (CVXPY) Feb 05 09:07:12 PM: Your problem has 20100 variables, 651 constraints, and 0 parameters.
# (CVXPY) Feb 05 09:07:12 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Feb 05 09:07:12 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Feb 05 09:07:12 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Feb 05 09:07:12 PM: Compiling problem (target solver=GUROBI).
# (CVXPY) Feb 05 09:07:12 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> GUROBI
# (CVXPY) Feb 05 09:07:12 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Feb 05 09:07:12 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) Feb 05 09:07:12 PM: Applying reduction QpMatrixStuffing
# (CVXPY) Feb 05 09:07:13 PM: Applying reduction GUROBI
# (CVXPY) Feb 05 09:07:13 PM: Finished problem compilation (took 3.593e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Feb 05 09:07:13 PM: Invoking solver GUROBI  to obtain a solution.
# Set parameter QCPDual to value 1
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[rosetta2])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 20500 rows, 20150 columns and 50400 nonzeros
# Model fingerprint: 0xcf988731
# Model has 50 quadratic objective terms
# Variable types: 10150 continuous, 10000 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [7e-05, 1e+00]
#   QObjective range [9e-01, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+00]
#
# User MIP start produced solution with objective 0 (0.01s)
# Loaded user MIP start with objective 0
#
# Presolve removed 20250 rows and 10100 columns
# Presolve time: 0.05s
# Presolved: 250 rows, 10050 columns, 20050 nonzeros
# Presolved model has 50 quadratic objective terms
# Variable types: 50 continuous, 10000 integer (10000 binary)
# Found heuristic solution: objective -54.9606694
#
# Root relaxation: objective -9.029596e+01, 857 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  -90.29596    0   94  -54.96067  -90.29596  64.3%     -    0s
# H    0     0                     -70.0224297  -90.29596  29.0%     -    0s
# H    0     0                     -84.0760221  -90.29596  7.40%     -    0s
# H    0     0                     -84.0919961  -90.29596  7.38%     -    0s
# H    0     0                     -84.1024485  -90.29596  7.36%     -    0s
# H    0     0                     -84.2171556  -90.29596  7.22%     -    0s
#      0     0  -90.28750    0   94  -84.21716  -90.28750  7.21%     -    0s
# H    0     0                     -84.2306734  -90.28750  7.19%     -    0s
# H    0     0                     -84.3324134  -90.28750  7.06%     -    0s
#      0     2  -90.28750    0   94  -84.33241  -90.28750  7.06%     -    0s
# H   32    40                     -84.3939805  -90.27193  6.96%  16.1    2s
# H   34    40                     -84.3971871  -90.27193  6.96%  15.8    2s
# H   36    40                     -84.3973721  -90.27193  6.96%  15.7    2s
# H   37    40                     -84.4371811  -90.27193  6.91%  15.8    2s
#   2708  2812  -88.25519  307   79  -84.43718  -90.27031  6.91%  13.4    5s
# H 6140  5995                     -84.4591937  -90.27031  6.88%  10.3    7s
# H 6152  5993                     -84.4621960  -90.27031  6.88%  10.3    7s
#   7524  6821  -90.24380   14   95  -84.46220  -90.26687  6.87%   9.5   10s
# H 7526  6481                     -84.4703488  -90.26687  6.86%   9.5   10s
#  12124  9806  -88.62349  338   83  -84.47035  -90.26521  6.86%  10.1   15s
#  17078 13160  -86.98323  648   69  -84.47035  -90.26521  6.86%   9.7   20s
#  22189 15597  -85.76565  954   58  -84.47035  -90.26521  6.86%   9.4   25s
#  28459 18616  -87.80669  341   81  -84.47035  -90.26344  6.86%   9.4   30s
#  34165 24110  -90.05345   33   91  -84.47035  -90.26025  6.85%   9.2   35s
# H37489 26153                     -84.4759454  -90.26025  6.85%   9.3   37s
#  40637 30058  -87.77299  452   75  -84.47595  -90.26025  6.85%   9.5   40s
#  48653 36895  -88.57095  225   82  -84.47595  -90.24317  6.83%   9.4   45s
#  59508 46960  -88.78447  241   89  -84.47595  -90.23070  6.81%   9.7   50s
#  72004 58314  -88.29112  328   79  -84.47595  -90.23022  6.81%   9.7   55s
#  83826 68959     cutoff 1051       -84.47595  -90.23022  6.81%   9.9   60s
#  91893 76637  -85.22984  930   60  -84.47595  -90.21926  6.80%  10.0   65s
#  104550 88229  -85.57503  910   68  -84.47595  -90.21528  6.79%  10.0   70s
#  117955 99936  -86.06710  171   75  -84.47595  -90.21139  6.79%  10.0   75s
#  130338 110861  -85.06734 1010   63  -84.47595  -90.20918  6.79%  10.1   80s
#  140352 120709  -85.83531  921   51  -84.47595  -90.20751  6.78%  10.2   85s
#  151472 130135  -84.73231 1066   70  -84.47595  -90.20665  6.78%  10.1   90s
#  160260 138366  -86.21413  410   81  -84.47595  -90.20496  6.78%  10.2   95s
#  166406 144794  -86.99149  709   71  -84.47595  -90.20496  6.78%  10.2  100s
#  176844 152924  -89.53411   40   83  -84.47595  -90.19959  6.78%  10.1  105s
#  185961 161201  -84.82149 1443   31  -84.47595  -90.19959  6.78%  10.1  110s
#  196390 170694  -89.52546   36   90  -84.47595  -90.19686  6.77%  10.0  115s
#  204777 178722  -88.44325  257   71  -84.47595  -90.19473  6.77%  10.1  120s
#  216485 187486  -88.79878  180   86  -84.47595  -90.19343  6.77%  10.0  125s
#  226844 196942  -88.98760  209   87  -84.47595  -90.19232  6.77%  10.0  130s
#  236611 206069  -88.18369   78   82  -84.47595  -90.19123  6.77%  10.0  135s
#  246323 214894  -89.83110   44   89  -84.47595  -90.18954  6.76%  10.1  140s
#  253604 219983  -86.96472  671   72  -84.47595  -90.18954  6.76%  10.0  146s
#  259234 225062  -85.48470  952   52  -84.47595  -90.18954  6.76%  10.0  150s
#
# Explored 259701 nodes (2598536 simplex iterations) in 150.01 seconds (213.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: -84.4759 -84.4703 -84.4622 ... -84.2307
#
# Time limit reached
# Best objective -8.447594541035e+01, best bound -9.018953960910e+01, gap 6.7636%
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Feb 05 09:09:43 PM: Problem status: user_limit
# (CVXPY) Feb 05 09:09:43 PM: Optimal value: -8.448e+01
# (CVXPY) Feb 05 09:09:43 PM: Compilation took 3.593e-01 seconds
# (CVXPY) Feb 05 09:09:43 PM: Solver (including time spent in interface) took 1.502e+02 seconds
# true_f=-84.47594541035264
# user_limit
# true_xf=array([2., 2., 3., 2., 2., 2., 1., 2., 1., 2., 2., 2., 3., 2., 3., 3., 2.,
#        2., 1., 2., 3., 2., 1., 1., 3., 1., 2., 2., 2., 2., 2., 3., 2., 2.,
#        1., 3., 1., 3., 2., 2., 2., 3., 2., 2., 2., 2., 2., 1., 2., 3.])
# /Users/parshakova.tanya/opt/anaconda3/envs/osbdo/lib/python3.9/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
plt.imshow(true_xp, aspect='auto')

# %%
true_lamb.shape, true_xp.size + true_xf.size
# Out:
# ((50,), 10050)

# %%
mra.assignment_problem_milp_solution_lamb(true_lamb, num_packages, num_fcs, econ, integer=True)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2606542
# Academic license - for non-commercial use only - expires 2026-01-06
# -90.29596327465502

# %%
fun_agents_eps = []
fun_agents_noisy_y = []

for i in range(num_packages):
    fun_agents_eps += [lambda lamb_k, K, i=i: mra.package_agent_query_multiple_actions(lamb_k, i, num_fcs,
                                                                                  econ, eps_sublevel=eps_sublevel, K=K,  
                                                                                  return_best=True, integer=True)]
    fun_agents_noisy_y += [lambda lamb_k, K, i=i: mra.package_agent_query_multiple_actions_noisy_prices(lamb_k, i, num_fcs,
                                                                                  econ, percent=percent, K=K,  
                                                                                  return_best=True, integer=True)]
 
for i in range(num_packages, num_packages+num_fcs):
    fun_agents_eps += [lambda lamb_k, K, i=i: mra.fc_agent_query_multiple_actions(lamb_k, i-num_packages, 
                                                                          econ, eps_sublevel=eps_sublevel, K=K, return_best=True)]
    fun_agents_noisy_y += [lambda lamb_k, K, i=i: mra.fc_agent_query_multiple_actions_noisy_prices(lamb_k, i-num_packages, 
                                                                          econ, percent=percent, K=K, return_best=True)]


fun_obj_val = lambda x_k: mra.assignment_problem_obj_val(x_k, num_packages, num_fcs, econ, integer=False)

# %% [markdown]
# # Localization

# %%
price_max = 3 * true_lamb.max()
price_min = (1./3) * true_lamb.min()
K_i = num_points
N = num_agents
primal_var_size = A_ineq.shape[1]

# %%
all_results_noisy_y, lamb_k_eps, _, x_k, _, mra_xk_noisy_y  = mra.price_localization_primal_recovery(fun_agents_noisy_y, fun_obj_val, primal_var_size, 
                                                                                                      A_ineq=A_ineq, b_ineq=b_ineq, 
                                                            price_max=price_max, price_min=price_min, alpha=alpha, relaxed=False, 
                                                            postprocessing=1, K_i=K_i, num_iters=100, 
                                                            method="accpm_l2", true_f=true_f, print_freq=5, eps_lamb=1e-28,
                                                            res_type=res_type, history=history,
                                                            mra_milp="gurobi")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2606542
# Academic license - for non-commercial use only - expires 2026-01-06
# Set parameter TimeLimit to value 300
# /Users/parshakova.tanya/Documents/projects/mra_precovery/mra/localization_prim_rec.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   lamb_rel_diff = np.linalg.norm(lamb_k - lamb_prev) / np.linalg.norm(lamb_prev)
# epoch=0, f_subopt_xk=1.3234E+00,  f_subopt_mra=1.3234E+00,  viol_xk=0.0000E+00, viol_mra=0.0000E+00, lamb_rel_diff=INF
# epoch=5, f_subopt_xk=8.1012E-01,  f_subopt_mra=4.2069E-01,  viol_xk=1.4773E+02, viol_mra=6.2791E+01, lamb_rel_diff=6.8410E-02
# epoch=10, f_subopt_xk=1.5100E-01,  f_subopt_mra=7.6012E-02,  viol_xk=4.3261E+01, viol_mra=1.5569E+01, lamb_rel_diff=6.1865E-02
# epoch=15, f_subopt_xk=9.1551E-02,  f_subopt_mra=7.3418E-02,  viol_xk=3.7987E+01, viol_mra=1.3459E+01, lamb_rel_diff=5.8851E-02
# epoch=20, f_subopt_xk=8.7610E-02,  f_subopt_mra=6.8016E-02,  viol_xk=3.6511E+01, viol_mra=1.1716E+01, lamb_rel_diff=5.8195E-02
# epoch=25, f_subopt_xk=8.3784E-02,  f_subopt_mra=6.9053E-02,  viol_xk=3.2882E+01, viol_mra=1.2187E+01, lamb_rel_diff=5.8115E-02
# epoch=30, f_subopt_xk=8.3717E-02,  f_subopt_mra=6.4394E-02,  viol_xk=3.7305E+01, viol_mra=1.2185E+01, lamb_rel_diff=5.5542E-02
# epoch=35, f_subopt_xk=8.8843E-02,  f_subopt_mra=6.2676E-02,  viol_xk=3.1475E+01, viol_mra=1.1936E+01, lamb_rel_diff=5.6912E-02
# epoch=40, f_subopt_xk=8.5098E-02,  f_subopt_mra=6.2531E-02,  viol_xk=3.5861E+01, viol_mra=1.1511E+01, lamb_rel_diff=5.3954E-02
# epoch=45, f_subopt_xk=8.2339E-02,  f_subopt_mra=6.0642E-02,  viol_xk=3.4164E+01, viol_mra=1.1504E+01, lamb_rel_diff=5.5486E-02
# epoch=50, f_subopt_xk=7.9055E-02,  f_subopt_mra=6.0981E-02,  viol_xk=3.4188E+01, viol_mra=1.1400E+01, lamb_rel_diff=5.4798E-02
# epoch=55, f_subopt_xk=8.0381E-02,  f_subopt_mra=6.0930E-02,  viol_xk=3.0698E+01, viol_mra=1.1534E+01, lamb_rel_diff=4.8891E-02
# epoch=60, f_subopt_xk=7.9884E-02,  f_subopt_mra=6.0857E-02,  viol_xk=3.4877E+01, viol_mra=1.1350E+01, lamb_rel_diff=5.2168E-02
# epoch=65, f_subopt_xk=7.8479E-02,  f_subopt_mra=5.7373E-02,  viol_xk=3.1343E+01, viol_mra=1.0859E+01, lamb_rel_diff=4.5300E-02
# epoch=70, f_subopt_xk=7.9853E-02,  f_subopt_mra=5.4080E-02,  viol_xk=3.2359E+01, viol_mra=1.0882E+01, lamb_rel_diff=4.8041E-02
# epoch=75, f_subopt_xk=8.3810E-02,  f_subopt_mra=5.7151E-02,  viol_xk=2.7798E+01, viol_mra=1.0860E+01, lamb_rel_diff=4.0049E-02
# epoch=80, f_subopt_xk=8.4989E-02,  f_subopt_mra=4.6579E-02,  viol_xk=2.1782E+01, viol_mra=1.0630E+01, lamb_rel_diff=3.8661E-02
# epoch=85, f_subopt_xk=7.4944E-02,  f_subopt_mra=4.7070E-02,  viol_xk=2.9475E+01, viol_mra=1.0463E+01, lamb_rel_diff=3.8270E-02
# epoch=90, f_subopt_xk=7.5069E-02,  f_subopt_mra=4.0153E-02,  viol_xk=2.2338E+01, viol_mra=1.0368E+01, lamb_rel_diff=3.4207E-02
# epoch=95, f_subopt_xk=7.5304E-02,  f_subopt_mra=4.4622E-02,  viol_xk=2.0827E+01, viol_mra=1.0290E+01, lamb_rel_diff=3.6695E-02
# epoch=99, f_subopt_xk=7.1389E-02,  f_subopt_mra=4.4618E-02,  viol_xk=2.7811E+01, viol_mra=1.0091E+01, lamb_rel_diff=2.5192E-02

# %%
all_results_eps, lamb_k_eps, _, x_k, _, mra_xk_eps  = mra.price_localization_primal_recovery(fun_agents_eps, fun_obj_val, primal_var_size, A_ineq=A_ineq, b_ineq=b_ineq, 
                                                            price_max=price_max, price_min=price_min, alpha=alpha, relaxed=False, 
                                                            postprocessing=1, K_i=K_i, num_iters=100, 
                                                            method="accpm_l2", true_f=true_f, print_freq=5, eps_lamb=1e-28,
                                                            res_type=res_type, history=history, mra_milp="gurobi")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2606542
# Academic license - for non-commercial use only - expires 2026-01-06
# Set parameter TimeLimit to value 300
# epoch=0, f_subopt_xk=1.3234E+00,  f_subopt_mra=1.3234E+00,  viol_xk=0.0000E+00, viol_mra=0.0000E+00, lamb_rel_diff=INF
# epoch=5, f_subopt_xk=8.1012E-01,  f_subopt_mra=6.4228E-01,  viol_xk=1.4773E+02, viol_mra=1.0927E+02, lamb_rel_diff=6.8410E-02
# epoch=10, f_subopt_xk=1.5100E-01,  f_subopt_mra=1.5067E-02,  viol_xk=4.3261E+01, viol_mra=1.2140E+01, lamb_rel_diff=6.1865E-02
# epoch=15, f_subopt_xk=9.1551E-02,  f_subopt_mra=9.5612E-02,  viol_xk=3.7987E+01, viol_mra=2.6638E+00, lamb_rel_diff=5.8851E-02
# epoch=20, f_subopt_xk=8.7610E-02,  f_subopt_mra=8.9614E-02,  viol_xk=3.6511E+01, viol_mra=2.9085E+00, lamb_rel_diff=5.8195E-02
# epoch=25, f_subopt_xk=8.3784E-02,  f_subopt_mra=9.8445E-02,  viol_xk=3.2882E+01, viol_mra=2.5822E+00, lamb_rel_diff=5.8115E-02
# epoch=30, f_subopt_xk=8.3717E-02,  f_subopt_mra=1.0710E-01,  viol_xk=3.7305E+01, viol_mra=3.8856E+00, lamb_rel_diff=5.5542E-02
# epoch=35, f_subopt_xk=8.8843E-02,  f_subopt_mra=1.1069E-01,  viol_xk=3.1475E+01, viol_mra=1.5229E+00, lamb_rel_diff=5.6912E-02
# epoch=40, f_subopt_xk=8.5098E-02,  f_subopt_mra=9.7367E-02,  viol_xk=3.5861E+01, viol_mra=2.0087E+00, lamb_rel_diff=5.3954E-02
# epoch=45, f_subopt_xk=8.2339E-02,  f_subopt_mra=1.1428E-01,  viol_xk=3.4164E+01, viol_mra=1.3132E+00, lamb_rel_diff=5.5486E-02
# epoch=50, f_subopt_xk=7.9055E-02,  f_subopt_mra=1.1178E-01,  viol_xk=3.4188E+01, viol_mra=2.5330E+00, lamb_rel_diff=5.4798E-02
# epoch=55, f_subopt_xk=8.0381E-02,  f_subopt_mra=1.1308E-01,  viol_xk=3.0698E+01, viol_mra=1.5476E+00, lamb_rel_diff=4.8891E-02
# epoch=60, f_subopt_xk=7.9884E-02,  f_subopt_mra=1.1690E-01,  viol_xk=3.4877E+01, viol_mra=1.2968E+00, lamb_rel_diff=5.2168E-02
# epoch=65, f_subopt_xk=7.8479E-02,  f_subopt_mra=INF,  viol_xk=3.1343E+01, viol_mra=1.1060E+00, lamb_rel_diff=4.5300E-02
# epoch=70, f_subopt_xk=7.9853E-02,  f_subopt_mra=INF,  viol_xk=3.2359E+01, viol_mra=1.0736E+00, lamb_rel_diff=4.8041E-02
# epoch=75, f_subopt_xk=8.3810E-02,  f_subopt_mra=1.3350E-01,  viol_xk=2.7798E+01, viol_mra=7.5959E-01, lamb_rel_diff=4.0049E-02
# epoch=80, f_subopt_xk=8.4989E-02,  f_subopt_mra=1.3892E-01,  viol_xk=2.1782E+01, viol_mra=5.8239E-01, lamb_rel_diff=3.8661E-02
# epoch=85, f_subopt_xk=7.4944E-02,  f_subopt_mra=1.3588E-01,  viol_xk=2.9475E+01, viol_mra=5.0827E-01, lamb_rel_diff=3.8270E-02
# /Users/parshakova.tanya/opt/anaconda3/envs/osbdo/lib/python3.9/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# epoch=90, f_subopt_xk=7.5069E-02,  f_subopt_mra=1.3783E-01,  viol_xk=2.2338E+01, viol_mra=4.4774E-01, lamb_rel_diff=3.4207E-02
# epoch=95, f_subopt_xk=7.5304E-02,  f_subopt_mra=1.4761E-01,  viol_xk=2.0827E+01, viol_mra=5.0107E-01, lamb_rel_diff=3.6695E-02
# epoch=99, f_subopt_xk=7.1389E-02,  f_subopt_mra=1.4746E-01,  viol_xk=2.7811E+01, viol_mra=3.5678E-01, lamb_rel_diff=2.5192E-02

# %%
mra_xk_eps[:-num_fcs].sum(), num_packages
# Out:
# (102.0, 200)

# %%
mra_xk_noisy_y[:-num_fcs].sum(), num_packages
# Out:
# (102.0, 200)

# %%
if len(all_results_noisy_y["subopt_xk"]) > len(all_results_eps["subopt_xk"]):
    all_res = all_results_noisy_y
else:
    all_res = all_results_eps

# %%
import pickle

with open(f"../results/{filename}_dict.pkl", "wb") as file:
    pickle.dump({"eps":all_results_eps, "noisy_y":all_results_noisy_y}, file)
with open(f"../results/{filename}_dict.pkl", "rb") as file:
    res = pickle.load(file)

# %%
all_results_eps.keys()
# Out:
# dict_keys(['f_xk', 'f_mra_xk', 'f_paver_xk', 'f_proj_xk', 'lagr_xk', 'lagr_mra_xk', 'lagr_paver_xk', 'lagr_proj_xk', 'viol_xk', 'viol_mra_xk', 'viol_paver_xk', 'viol_proj_xk', 'viol_primal_xk', 'viol_primal_mra_xk', 'viol_primal_paver_xk', 'viol_primal_proj_xk', 'viol_primal_compl_xk', 'viol_primal_compl_mra_xk', 'viol_primal_compl_paver_xk', 'viol_primal_compl_proj_xk', 'subopt_xk', 'subopt_mra_xk', 'subopt_paver_xk', 'subopt_proj_xk', 'prices_deltas'])

# %%
print("sub_eps", np.array(all_results_eps["viol_primal_mra_xk"]).size,
      "noisy_y", np.array(all_results_noisy_y["viol_primal_mra_xk"]).size)
# Out:
# sub_eps 100 noisy_y 100

# %%
mra.plot_all_methods_metrics_4x(all_results_eps, all_results_noisy_y, true_f, 
                                b_norm, percent, eps_sublevel, filename)
